# %%
import streamlit as st
import joblib
import numpy as np

# %%
# !pip install streamlit

# %%
st.title("Curn Analysis")
# Out:
# 2025-10-20 19:13:57.254 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:13:59.343
# ...
#   command:
#
#     streamlit run C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-10-20 19:13:59.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:13:59.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.divider()
# Out:
# 2025-10-20 19:14:02.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:02.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:02.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
#st.write()

# %%
gender = st.selectbox("Gender", [0, 1], format_func=lambda x: "Male" if x == 1 else "Female")
SeniorCitizen = st.selectbox("Senior Citizen", [0, 1])
Partner = st.selectbox("Partner", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
Dependents = st.selectbox("Dependents", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
tenure = st.number_input("Tenure (Months)", min_value=0, max_value=100, step=1)
PhoneService = st.selectbox("Phone Service", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
MultipleLines = st.selectbox("Multiple Lines", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
InternetService = st.selectbox("Internet Service", [0, 1, 2], format_func=lambda x: ["DSL", "Fiber optic", "No"][x])
OnlineSecurity = st.selectbox("Online Security", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
OnlineBackup = st.selectbox("Online Backup", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")

DeviceProtection = st.selectbox("Device Protection", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
TechSupport = st.selectbox("Tech Support", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
StreamingTV = st.selectbox("Streaming TV", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
StreamingMovies = st.selectbox("Streaming Movies", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
Contract = st.selectbox("Contract", [0, 1, 2], format_func=lambda x: ["Month-to-month", "One year", "Two year"][x])
PaperlessBilling = st.selectbox("Paperless Billing", [0, 1], format_func=lambda x: "Yes" if x == 1 else "No")
PaymentMethod = st.selectbox("Payment Method", [0, 1, 2, 3], format_func=lambda x: ["Electronic check", "Mailed check", "Bank transfer", "Credit card"][x])
MonthlyCharges = st.number_input("Monthly Charges", min_value=0.0, step=0.5)
TotalCharges = st.number_input("Total Charges", min_value=0.0, step=0.5)
# Out:
# 2025-10-20 19:14:08.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:08.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:08.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:08.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:08.820 Session state does not function when running a script without `streamlit run`
# 2025-10-20 19:14:08.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:08.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:14:08.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.divider()
# Out:
# 2025-10-20 19:15:04.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:15:04.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:15:04.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
predBtn = st.button("Predict!")
# Out:
# 2025-10-20 19:15:54.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:15:54.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:15:54.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:15:54.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:15:54.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-20 19:15:54.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if predBtn:
    data = {
        'gender': gender,
        'SeniorCitizen': SeniorCitizen,
        'Partner': Partner,
        'Dependents': Dependents,
        'tenure': tenure,
        'PhoneService': PhoneService,
        'MultipleLines': MultipleLines,
        'InternetService': InternetService,
        'OnlineSecurity': OnlineSecurity,
        'OnlineBackup': OnlineBackup,
        'DeviceProtection': DeviceProtection,
        'TechSupport': TechSupport,
        'StreamingTV': StreamingTV,
        'StreamingMovies': StreamingMovies,
        'Contract': Contract,
        'PaperlessBilling': PaperlessBilling,
        'PaymentMethod': PaymentMethod,
        'MonthlyCharges': MonthlyCharges,
        'TotalCharges': TotalCharges
    }
    
    X_array = scaler_transform([data])
    
    predictions = model.predict(X_array)[0]
    
    st.write(prediction)

# %%
# !streamlit run UI.ipynb
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Streamlit requires raw Python (.py) files, not .ipynb.
# For more information, please see https://docs.streamlit.io
